# %% [markdown]
# # Data Structures in Python
# ### Latin American Economic Data Exercises
#
# In these exercises, you will work as a Junior Data Analyst at the **Banco Interamericano de Desarrollo (BID)**, using Python data structures to clean, organize, and analyze economic data from Latin America.
#
# Each exercise builds on core data structure concepts:
# - **Lists**: indexing, slicing, mutability
# - **Dictionaries**: key-value pairs, updates
# - **Tuples**: immutability, unpacking
# - **`zip()`**: pairing parallel sequences
# - **`sorted()` + `lambda`**: custom sorting
# - **Nested dictionaries**: hierarchical data
#
# ---

# %% [markdown]
# ## Exercise 1: Cleaning Andean GDP Growth Data
# **Difficulty:** Easy
#
# You have received raw data for a report on the Andean region. The data consists of two parallel lists: one with country names and another with their GDP growth percentages. However, two mistakes were made:
#
# 1. Peru's GDP growth is recorded as `-99.9` (a typo) — the correct figure is `2.5`.
# 2. The lists include Brazil and Argentina at the end, but this report should only cover the **Andean nations** (the first four entries).
#
# ### Task
#
# **Step 1** — Initialize the following lists:
# - `countries`: `"Colombia"`, `"Ecuador"`, `"Peru"`, `"Bolivia"`, `"Brazil"`, `"Argentina"`
# - `gdp_growth`: `1.2`, `0.8`, `-99.9`, `1.5`, `2.9`, `-1.6`
#
# **Step 2** — Fix the error: access the element at **index 2** (Peru) and replace `-99.9` with `2.5`.
#
# **Step 3** — Create `andean_countries` and `andean_growth` by **slicing** the first 4 elements from each list.
#
# **Step 4** — Print both cleaned lists.
#
# ### Expected Output
# ```
# ['Colombia', 'Ecuador', 'Peru', 'Bolivia']
# [1.2, 0.8, 2.5, 1.5]
# ```

# %%
# Exercise 1: Cleaning Andean GDP Growth Data

# %% [markdown]
# ---
# ## Exercise 2: Updating Chile's Economic Profile
# **Difficulty:** Easy
#
# You work on the Chile desk at the BID. You have a dictionary containing the country's current economic profile, including a tuple for the geographic coordinates of Santiago. A new report shows inflation has dropped, and the GIS team needs the coordinates separated for their map dashboard.
#
# ### Task
#
# **Step 1** — Create a dictionary with these key-value pairs:
# - `'country'`: `'Chile'`
# - `'inflation'`: `7.6`
# - `'coordinates'`: `(-33.4489, -70.6693)`
#
# **Step 2** — Update the `'inflation'` value to `4.5`.
#
# **Step 3** — Use **tuple unpacking** to extract the coordinates into `latitude` and `longitude` variables.
#
# **Step 4** — Print the updated dictionary, then the latitude and longitude on separate lines.
#
# ### Expected Output
# ```
# {'country': 'Chile', 'inflation': 4.5, 'coordinates': (-33.4489, -70.6693)}
# Latitude: -33.4489
# Longitude: -70.6693
# ```

# %%
# Exercise 2: Updating Chile's Economic Profile

# %% [markdown]
# ---
# ## Exercise 3: Merging Unemployment Data Sources
# **Difficulty:** Medium
#
# You have received raw data from two different departments. One sent a list of country names (`paises`), and the other sent a matching list of unemployment rates (`desempleo`). Storing these in separate lists is risky because sorting or modifying one list without the other would break the data alignment. You need to merge them into a single dictionary.
#
# ### Task
#
# 1. Initialize the two lists:
#    - `paises`: `"Colombia"`, `"México"`, `"Chile"`, `"Perú"`, `"Argentina"`
#    - `desempleo`: `10.2`, `2.8`, `8.5`, `5.4`, `6.2`
#
# 2. Create a new dictionary using **`zip()`** to pair the elements and **`dict()`** to convert them.
#
# 3. Print the resulting dictionary.
#
# ### Expected Output
# ```
# {'Colombia': 10.2, 'México': 2.8, 'Chile': 8.5, 'Perú': 5.4, 'Argentina': 6.2}
# ```

# %%
# Exercise 3: Merging Unemployment Data Sources

# %% [markdown]
# ---
# ## Exercise 4: Ranking Countries by GDP Growth
# **Difficulty:** Hard
#
# You have two parallel lists: `countries` and `gdp_growth`. Your goal is to generate a report ranking these countries from lowest to highest GDP growth to prioritize financial aid. Sorting these lists individually is dangerous because it breaks the link between a country and its data. You need to combine the data before sorting.
#
# ### Task
#
# 1. Combine `countries` and `gdp_growth` into a single **list of tuples** using `zip()`.
# 2. Sort this combined list from **lowest to highest** growth using `sorted()`.
# 3. Use a **`lambda`** function as the `key` argument to sort by the numeric growth value (the second element of each tuple).
# 4. Print the final sorted list of tuples.
#
# **Data:**
# ```python
# countries = ['Chile', 'Argentina', 'Colombia', 'Mexico', 'Peru']
# gdp_growth = [0.2, -1.6, 1.2, 3.2, -0.6]
# ```
#
# ### Expected Output
# ```
# [('Argentina', -1.6), ('Peru', -0.6), ('Chile', 0.2), ('Colombia', 1.2), ('Mexico', 3.2)]
# ```

# %%
# Exercise 4: Ranking Countries by GDP Growth

# %% [markdown]
# ---
# ## Exercise 5: Restructuring Economic Indicators
# **Difficulty:** Hard
#
# You have identified a critical flaw in the current data storage: keeping countries and their economic indicators in separate lists allows them to become misaligned. To prevent data corruption, you must restructure the raw data into a single **nested dictionary** that permanently links each country to its specific metrics.
#
# ### Task
#
# 1. Using the provided lists, iterate through them to build a dictionary called `latam_data` where the **key** is the country name.
# 2. The **value** for each country must be a nested dictionary with the keys `'gdp'`, `'inflation'`, and `'unemployment'`.
# 3. Print the resulting `latam_data` dictionary.
# 4. Print only **Chile's inflation** rate in the format shown below.
#
# **Data:**
# ```python
# countries = ["Colombia", "Mexico", "Chile", "Peru"]
# gdp = [334.7, 1322.7, 335.5, 240.3]
# inflation = [9.28, 4.66, 7.56, 3.24]
# unemployment = [10.2, 2.8, 8.5, 5.4]
# ```
#
# ### Expected Output
# ```
# {'Colombia': {'gdp': 334.7, 'inflation': 9.28, 'unemployment': 10.2}, 'Mexico': {'gdp': 1322.7, 'inflation': 4.66, 'unemployment': 2.8}, 'Chile': {'gdp': 335.5, 'inflation': 7.56, 'unemployment': 8.5}, 'Peru': {'gdp': 240.3, 'inflation': 3.24, 'unemployment': 5.4}}
# Chile's Inflation: 7.56%
# ```

# %%
# Exercise 5: Restructuring Economic Indicators
