# %% [markdown]
# # GDP Per Capita Calculator
#
# **Difficulty:** Easy | **Category:** Syntax and Data Types
#
# ---
#
# ## Context
#
# You've been hired as a junior analyst at Colombia's Ministry of Finance. Your first task is to process the country's Gross Domestic Product (GDP) figures and calculate a key economic indicator: **GDP per capita** (GDP divided by population).
#
# This metric tells us how much economic output is produced per person, and it's one of the most common ways to measure a country's standard of living.
#
# ---
#
# ## Input Data (Colombia, 2024)
#
# | Variable | Value | Unit |
# |----------|-------|------|
# | Total GDP | 1,706,447,000 | million COP |
# | Population | 52.97 | million people |
#
# ---
#
# ## Important Concepts
#
# - **Numeric types vs Strings:** In Python, `1706447000` is a number, but `"1706447000"` (with quotes) is a string. You can only do math with numbers!
# - **Division operator:** Use `/` for division (not `\`)
# - **Formula:** GDP per capita = GDP / Population

# %% [markdown]
# ---
#
# ## Milestone 1: Define the Variables
#
# Create two variables to store the economic data:
# - `gdp_total` should hold the GDP value in millions of COP
# - `population` should hold the population in millions
#
# **Remember:** These must be numeric values (integers or floats), not strings!

# %%
# Define your variables here
gdp_total = 
population =

# %% [markdown]
# ---
#
# ## Milestone 2: Calculate GDP Per Capita
#
# Create a variable called `gdp_per_capita` that calculates GDP divided by population.
#
# **Think carefully:** Which number should be divided by which?

# %%
# Calculate GDP per capita
gdp_per_capita =

# %% [markdown]
# ---
#
# ## Milestone 3: Display the Result
#
# Print the `gdp_per_capita` value to show the result.

# %%
# Print the result

# %% [markdown]
# ---
#
# ## Expected Output
#
# If your code is correct, you should see:
#
# ```
# 32215348.310364358
# ```
#
# ---
