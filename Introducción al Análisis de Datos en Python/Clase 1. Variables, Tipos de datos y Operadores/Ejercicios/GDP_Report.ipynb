# %% [markdown]
# # GDP Financial Report
#
# **Difficulty:** Easy | **Category:** Syntax and Data Types
#
# ---
#
# ## Context
#
# Building on your GDP per capita calculation, your supervisor at the Ministry of Finance now needs a **professional financial report** that presents the data clearly to international stakeholders.
#
# The report must:
# 1. Show the GDP per capita in Colombian Pesos (COP)
# 2. Convert it to US Dollars (USD) using the current exchange rate
# 3. Format all numbers with thousand separators and exactly 2 decimal places
#
# ---
#
# ## Input Data
#
# | Variable | Value | Unit |
# |----------|-------|------|
# | GDP per capita | 32,215,348.31 | COP |
# | Exchange rate (TRM) | 3,637.88 | COP per USD |
#
# ---
#
# ## Important Concepts
#
# ### Currency Conversion
# To convert **FROM** local currency **TO** foreign currency, you **divide** by the exchange rate:
# ```
# USD = COP / exchange_rate
# ```
#
# ### F-strings for Formatting
# - Basic: `f"The value is {variable}"`
# - With 2 decimals: `f"Value: {variable:.2f}"`
# - With thousands separator and 2 decimals: `f"Value: {variable:,.2f}"`

# %% [markdown]
# ---
#
# ## Milestone 1: Define the Variables
#
# Create variables for:
# - `gdp_per_capita_cop` with the GDP per capita value in COP
# - `exchange_rate` with the TRM value

# %%
# Define your variables here
gdp_per_capita_cop = 
exchange_rate =

# %% [markdown]
# ---
#
# ## Milestone 2: Convert to USD
#
# Create a variable `gdp_per_capita_usd` that converts COP to USD.
#
# **Think carefully:** Should you multiply or divide by the exchange rate?

# %%
# Convert COP to USD
gdp_per_capita_usd =

# %% [markdown]
# ---
#
# ## Milestone 3: Generate the Formatted Report
#
# Print a clean report with:
# - A header line: `=== GDP Per Capita Report ===`
# - GDP per capita in COP (formatted with commas and 2 decimal places)
# - The exchange rate (formatted with commas and 2 decimal places)
# - GDP per capita in USD (formatted with commas and 2 decimal places)
#
# **Hint:** Use f-strings with the format specifier `:,.2f`

# %%
# Generate the formatted report
print("=== GDP Per Capita Report ===")

# Print GDP per capita in COP

# Print exchange rate

# Print GDP per capita in USD

# %% [markdown]
# ---
#
# ## Expected Output
#
# If your code is correct, you should see:
#
# ```
# === GDP Per Capita Report ===
# GDP per capita (COP): 32,215,348.31
# Exchange rate (COP/USD): 3,637.88
# GDP per capita (USD): 8,855.53
# ```
